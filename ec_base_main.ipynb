# %%
import json
import torch
import seaborn
import matplotlib as mpl
import matplotlib.pyplot as plt
from ec_base_model import get_ec_batch, EC, ECData
from ec_gen_train import Trainer, name_list

mpl.rcParams['font.sans-serif'] = ['DengXian']  
mpl.rcParams['axes.unicode_minus'] = False

# %%
with open('./problem_data_a.json', 'r', encoding='utf8')as fp:
    data = json.load(fp)
with open('glove.6B.50d.txt', 'rb') as f:
    lines = f.readlines()

# %%
name_dict = dict()
for i, name in enumerate(name_list):
    name_dict[name] = i

# %%
trained_dict = dict()
for i in range(len(lines)):
    line = lines[i].split()
    trained_dict[line[0].decode("utf-8").upper()] = [float(line[j]) for j in range(1, 51)]

# %%
alpha = 0.0003
epoch_num = 150
mid_size = 64
batch_size = 16
weight_decay = 5e-5
test_rate = 0.15

# %%
glove = ECData(data=data, name_dict=name_dict, trained_dict=trained_dict, 
                       train_path='./ec_train_base.json', test_path='./ec_test_base.json')
glove.get_words()
glove.get_id()

# %%
train_data = get_ec_batch(glove.train_content, glove.train_y, batch_size)
test_data = get_ec_batch(glove.test_content, glove.test_y, batch_size)
print(len(train_data), len(test_data), len(test_data) / (len(test_data) + len(train_data)))
# Out:
# 81 12 0.12903225806451613

# %%
torch.manual_seed(0)
torch.cuda.manual_seed(0)
tra_acc1, tes_acc1 = list(), list()
tra_acc2, tes_acc2 = list(), list()
tra_acc3, tes_acc3 = list(), list()
tra_loss, tes_loss = list(), list()
tra_hit1, tes_hit1 = list(), list()
tra_hit2, tes_hit2 = list(), list()
tra_hit3, tes_hit3 = list(), list()

# %%
model = EC(inp_size=50, mid_size=mid_size, num_words=glove.word_num, num_types=len(name_list), num_layers=1,
              weight=torch.tensor(glove.embedding, dtype=torch.float))
# Out:
# d:\pycharmprojects\ecnu-eduktm\venv\lib\site-packages\torch\nn\modules\rnn.py:61: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %%
trainer = Trainer(model=model, train_data=train_data, epoch_num=epoch_num,
                  batch_size=batch_size, alpha=alpha, weight_decay=weight_decay)
epoch = 0

# %%
for epoch in range(epoch_num):
    loss_tot = torch.Tensor([0]).cuda()
    loss_tot += trainer.train_func()

    train_loss, train_acc1, train_acc2, train_acc3, train_hit1, train_hit2, train_hit3 = trainer.model_eval(train_data)
    test_loss, test_acc1, test_acc2, test_acc3, test_hit1, test_hit2, test_hit3 = trainer.model_eval(test_data)
    
    if epoch % 25 == 0 or (len(tra_acc2) > 0 and train_acc2 - tra_acc2[-1] > 0.049):
        torch.save(trainer.model.state_dict(), './results/ec_base_epoch/ec_base_epoch_%d.pt' % epoch)

    tra_loss.append(train_loss / len(train_data) / batch_size)
    tes_loss.append(test_loss / len(test_data) / batch_size)
    tra_acc1.append(train_acc1)
    tes_acc1.append(test_acc1)
    tra_acc2.append(train_acc2)
    tes_acc2.append(test_acc2)
    tra_acc3.append(train_acc3)
    tes_acc3.append(test_acc3)
    tra_hit1.append(train_hit1)
    tes_hit1.append(test_hit1)
    tra_hit2.append(train_hit2)
    tes_hit2.append(test_hit2)
    tra_hit3.append(train_hit3)
    tes_hit3.append(test_hit3)
    print("---------- iteration", epoch + 1, "----------")
    print("total loss:", loss_tot.item())
    print("train loss:", train_loss / len(train_data), ", ", "test loss:", test_loss / len(test_data))
    print("train acc:", train_acc1, ", ", "test acc:", test_acc1)
    print("train hit:", train_hit2, ", ", "test hit:", test_hit2)
    if train_acc1 > 0.8 and test_acc1 > 0.32:
        break
# Out:
# D:\PyCharmProjects\ecnu-EduKTM\paper2a\ec_gen_train.py:67: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   acc = torch.mean((torch.tensor(pred == y, dtype=torch.float)))
# ---------- iteration 1 ----------
# total loss: 595.2556762695312
# train loss: 6.839138178177822 ,  test loss: 6.450268824895223
# train acc: 0.009259259259259259 ,  test acc: 0.015625
# train hit: 0.7500656239780379 ,  test hit: 0.7812510877847672
# ---------- iteration 2 ----------
# total loss: 553.5730590820312
# train loss: 6.600168993443619 ,  test loss: 6.176093975702922
# train acc: 0.016975308641975308 ,  test acc: 0.046875
# train hit: 0.7649832470917407 ,  test hit: 0.807292585571607
# ---------- iteration 3 ----------
# total loss: 531.9522705078125
# train loss: 6.076358571464633 ,  test loss: 5.908779978752136
# train acc: 0.016975308641975308 ,  test acc: 0.041666666666666664
# train hit: 0.7374629738890095 ,  test hit: 0.7352447211742401
# ---------- iteration 4 ----------
# total loss: 494.3421630859375
# train loss: 5.861622763268741 ,  test loss: 5.754115184148152
# train acc: 0.08564814814814815 ,  test acc: 0.07291666666666667
# train hit: 0.6920028424557344 ,  test hit: 0.6809914708137512
# ---------- iteration 5 ----------
# total loss: 484.6722717285156
# train loss: 5.735260674982895 ,  test loss: 5.620803078015645
# train acc: 0.1388888888888889 ,  test acc: 0.10416666666666667
# train hit: 0.6758635183911265 ,  test hit: 0.6692727704842886
# ---------- iteration 6 ----------
# total loss: 476.1739196777344
# train loss: 5.71062057989615 ,  test loss: 5.588305791219075
# train acc: 0.17669753086419754 ,  test acc: 0.18229166666666666
# train hit: 0.6359975006845262 ,  test hit: 0.6384570052226385
# ---------- iteration 7 ----------
# total loss: 471.4451904296875
# train loss: 5.596915521739442 ,  test loss: 5.458897590637207
# train acc: 0.16358024691358025 ,  test acc: 0.15104166666666666
# train hit: 0.6708480899716601 ,  test hit: 0.6579880913098654
# ---------- iteration 8 ----------
# total loss: 462.08453369140625
# train loss: 5.544458683626152 ,  test loss: 5.387150128682454
# train acc: 0.17824074074074073 ,  test acc: 0.17708333333333334
# train hit: 0.6520082060201668 ,  test hit: 0.657120073835055
# ---------- iteration 9 ----------
# total loss: 456.24334716796875
# train loss: 5.48746238520116 ,  test loss: 5.3755738735198975
# train acc: 0.1736111111111111 ,  test acc: 0.17708333333333334
# train hit: 0.6465426999845623 ,  test hit: 0.6545158922672272
# ---------- iteration 10 ----------
# total loss: 451.3286437988281
# train loss: 5.444152890900035 ,  test loss: 5.368343830108643
# train acc: 0.17978395061728394 ,  test acc: 0.18229166666666666
# train hit: 0.6518795983290967 ,  test hit: 0.6458353996276855
# ---------- iteration 11 ----------
# total loss: 448.39453125
# train loss: 5.438650337266333 ,  test loss: 5.3569802443186445
# train acc: 0.17669753086419754 ,  test acc: 0.19270833333333334
# train hit: 0.66216759107731 ,  test hit: 0.6566860377788544
# ---------- iteration 12 ----------
# total loss: 440.86199951171875
# train loss: 5.377700181654942 ,  test loss: 5.409112373987834
# train acc: 0.18055555555555555 ,  test acc: 0.17708333333333334
# train hit: 0.6710410000365458 ,  test hit: 0.6519117504358292
# ---------- iteration 13 ----------
# total loss: 437.656005859375
# train loss: 5.2876921171023525 ,  test loss: 5.329759359359741
# train acc: 0.19290123456790123 ,  test acc: 0.19270833333333334
# train hit: 0.6688547892335021 ,  test hit: 0.6553839395443598
# ---------- iteration 14 ----------
# total loss: 431.7217712402344
# train loss: 5.1952508879296575 ,  test loss: 5.248394926389058
# train acc: 0.19675925925925927 ,  test acc: 0.171875
# train hit: 0.6851869836265658 ,  test hit: 0.655383954445521
# ---------- iteration 15 ----------
# total loss: 424.5332946777344
# train loss: 5.110126159809254 ,  test loss: 5.233646392822266
# train acc: 0.20833333333333334 ,  test acc: 0.1875
# train hit: 0.676506483628426 ,  test hit: 0.6471374730269114
# ---------- iteration 16 ----------
# total loss: 418.97369384765625
# train loss: 5.082359140301928 ,  test loss: 5.239685932795207
# train acc: 0.20833333333333334 ,  test acc: 0.18229166666666666
# train hit: 0.685315579543879 ,  test hit: 0.6506096571683884
# ---------- iteration 17 ----------
# total loss: 414.39361572265625
# train loss: 4.904580622543524 ,  test loss: 5.108302036921184
# train acc: 0.2199074074074074 ,  test acc: 0.171875
# train hit: 0.6929672669481348 ,  test hit: 0.6440992603699366
# ---------- iteration 18 ----------
# total loss: 402.204345703125
# train loss: 4.804253860756203 ,  test loss: 5.145562132199605
# train acc: 0.22145061728395063 ,  test acc: 0.17708333333333334
# train hit: 0.7222880640147645 ,  test hit: 0.6627623538176218
# ---------- iteration 19 ----------
# total loss: 387.9664001464844
# train loss: 4.603770420875079 ,  test loss: 5.009552001953125
# train acc: 0.22762345679012347 ,  test acc: 0.18229166666666666
# train hit: 0.7499369978904724 ,  test hit: 0.6762170344591141
# ---------- iteration 20 ----------
# total loss: 372.99053955078125
# train loss: 4.409637724911725 ,  test loss: 4.867885073026021
# train acc: 0.24382716049382716 ,  test acc: 0.17708333333333334
# train hit: 0.758746091230416 ,  test hit: 0.6822933952013651
# ---------- iteration 21 ----------
# total loss: 359.3877258300781
# train loss: 4.26583672452856 ,  test loss: 4.736115614573161
# train acc: 0.25540123456790126 ,  test acc: 0.171875
# train hit: 0.7636971701810389 ,  test hit: 0.6931439538796743
# ---------- iteration 22 ----------
# total loss: 350.42645263671875
# train loss: 4.267154396316151 ,  test loss: 4.74677836894989
# train acc: 0.2515432098765432 ,  test acc: 0.17708333333333334
# train hit: 0.7424138799125766 ,  test hit: 0.6658004075288773
# ---------- iteration 23 ----------
# total loss: 332.5643310546875
# train loss: 4.047443984467306 ,  test loss: 4.653846979141235
# train acc: 0.2654320987654321 ,  test acc: 0.171875
# train hit: 0.7593247868396618 ,  test hit: 0.6736128181219101
# ---------- iteration 24 ----------
# total loss: 319.5374755859375
# train loss: 3.8359588664255027 ,  test loss: 4.555980384349823
# train acc: 0.2716049382716049 ,  test acc: 0.17708333333333334
# train hit: 0.7735350845772543 ,  test hit: 0.6753489226102829
# ---------- iteration 25 ----------
# total loss: 308.3761291503906
# train loss: 3.8265085426377663 ,  test loss: 4.640979766845703
# train acc: 0.2762345679012346 ,  test acc: 0.18229166666666666
# train hit: 0.7731493321465858 ,  test hit: 0.6532136996587118
# ---------- iteration 26 ----------
# total loss: 293.9714050292969
# train loss: 3.5971592443960683 ,  test loss: 4.543003857135773
# train acc: 0.2932098765432099 ,  test acc: 0.171875
# train hit: 0.7936610189484962 ,  test hit: 0.6636302868525187
# ---------- iteration 27 ----------
# total loss: 283.0341491699219
# train loss: 3.554929659690386 ,  test loss: 4.738064825534821
# train acc: 0.2847222222222222 ,  test acc: 0.19270833333333334
# train hit: 0.7922464410463969 ,  test hit: 0.6592901200056076
# ---------- iteration 28 ----------
# total loss: 268.5306396484375
# train loss: 3.463465001848009 ,  test loss: 4.607198456923167
# train acc: 0.2986111111111111 ,  test acc: 0.16666666666666666
# train hit: 0.8006054346944079 ,  test hit: 0.659724086523056
# ---------- iteration 29 ----------
# total loss: 257.49737548828125
# train loss: 3.297601526166186 ,  test loss: 4.482110500335693
# train acc: 0.30324074074074076 ,  test acc: 0.171875
# train hit: 0.7904460106366946 ,  test hit: 0.6510435690482458
# ---------- iteration 30 ----------
# total loss: 248.56719970703125
# train loss: 3.2528284861717696 ,  test loss: 4.461374243100484
# train acc: 0.2839506172839506 ,  test acc: 0.16145833333333334
# train hit: 0.7586817778187034 ,  test hit: 0.6319464643796285
# ---------- iteration 31 ----------
# total loss: 238.38851928710938
# train loss: 3.1006252059230097 ,  test loss: 4.400454739729564
# train acc: 0.3248456790123457 ,  test acc: 0.171875
# train hit: 0.78671658112679 ,  test hit: 0.6458352655172348
# ---------- iteration 32 ----------
# total loss: 227.61380004882812
# train loss: 3.0796595561651534 ,  test loss: 4.486652036507924
# train acc: 0.32947530864197533 ,  test acc: 0.17708333333333334
# train hit: 0.7622182619424513 ,  test hit: 0.6197937925656637
# ---------- iteration 33 ----------
# total loss: 214.8603515625
# train loss: 2.7921190526750355 ,  test loss: 4.314568082491557
# train acc: 0.4390432098765432 ,  test acc: 0.2708333333333333
# train hit: 0.7732135432737844 ,  test hit: 0.6176235775152842
# ---------- iteration 34 ----------
# total loss: 210.82171630859375
# train loss: 2.719572157035639 ,  test loss: 4.221289912859599
# train acc: 0.4567901234567901 ,  test acc: 0.2552083333333333
# train hit: 0.7730849576585087 ,  test hit: 0.6267380764087042
# ---------- iteration 35 ----------
# total loss: 205.5283660888672
# train loss: 2.6306502907364457 ,  test loss: 4.325418591499329
# train acc: 0.4930555555555556 ,  test acc: 0.2760416666666667
# train hit: 0.7869737729614164 ,  test hit: 0.6154534469048182
# ---------- iteration 36 ----------
# total loss: 191.4937286376953
# train loss: 2.7419473889433306 ,  test loss: 4.181579411029816
# train acc: 0.4351851851851852 ,  test acc: 0.2708333333333333
# train hit: 0.7620896365907457 ,  test hit: 0.6176235924164454
# ---------- iteration 37 ----------
# total loss: 186.9146728515625
# train loss: 2.4491713179482355 ,  test loss: 4.085217555363973
# train acc: 0.4992283950617284 ,  test acc: 0.296875
# train hit: 0.7777145379855309 ,  test hit: 0.637588694691658
# ---------- iteration 38 ----------
# total loss: 179.27618408203125
# train loss: 2.3547947421485995 ,  test loss: 4.128182291984558
# train acc: 0.5393518518518519 ,  test acc: 0.2760416666666667
# train hit: 0.8015698694888457 ,  test hit: 0.634550521771113
# ---------- iteration 39 ----------
# total loss: 174.51295471191406
# train loss: 2.3704794689461037 ,  test loss: 4.072424650192261
# train acc: 0.5501543209876543 ,  test acc: 0.28125
# train hit: 0.8081284974828179 ,  test hit: 0.6401928315560023
# ---------- iteration 40 ----------
# total loss: 172.87599182128906
# train loss: 2.38075147587576 ,  test loss: 4.125676174958547
# train acc: 0.5455246913580247 ,  test acc: 0.28125
# train hit: 0.7990621799304162 ,  test hit: 0.6284741957982382
# ---------- iteration 41 ----------
# total loss: 166.37966918945312
# train loss: 2.38698156527531 ,  test loss: 4.285928428173065
# train acc: 0.5895061728395061 ,  test acc: 0.2760416666666667
# train hit: 0.8197668194770813 ,  test hit: 0.6414949099222819
# ---------- iteration 42 ----------
# total loss: 168.55673217773438
# train loss: 2.257304365252271 ,  test loss: 4.033678452173869
# train acc: 0.5185185185185185 ,  test acc: 0.28125
# train hit: 0.7833729562936006 ,  test hit: 0.6232658326625824
# ---------- iteration 43 ----------
# total loss: 162.7252197265625
# train loss: 2.154066081400271 ,  test loss: 4.036821722984314
# train acc: 0.5748456790123457 ,  test acc: 0.2760416666666667
# train hit: 0.8137226045867543 ,  test hit: 0.6371546487013499
# ---------- iteration 44 ----------
# total loss: 152.7725067138672
# train loss: 2.211361989562894 ,  test loss: 4.030442635218303
# train acc: 0.5216049382716049 ,  test acc: 0.28125
# train hit: 0.7883883346745997 ,  test hit: 0.6284741659959158
# ---------- iteration 45 ----------
# total loss: 146.16127014160156
# train loss: 2.0123667687545588 ,  test loss: 4.011941889921824
# train acc: 0.5671296296296297 ,  test acc: 0.296875
# train hit: 0.8008625669243895 ,  test hit: 0.6319463600715002
# ---------- iteration 46 ----------
# total loss: 145.26983642578125
# train loss: 2.0683861529385603 ,  test loss: 4.1674419442812605
# train acc: 0.566358024691358 ,  test acc: 0.2760416666666667
# train hit: 0.8004124694400363 ,  test hit: 0.6241339246431986
# ---------- iteration 47 ----------
# total loss: 141.77273559570312
# train loss: 1.9302689293284474 ,  test loss: 4.131982664267222
# train acc: 0.5694444444444444 ,  test acc: 0.2916666666666667
# train hit: 0.8006696583312235 ,  test hit: 0.6232658425966898
# ---------- iteration 48 ----------
# total loss: 136.833740234375
# train loss: 1.7071988295625757 ,  test loss: 4.091480274995168
# train acc: 0.625 ,  test acc: 0.3177083333333333
# train hit: 0.8269040952494116 ,  test hit: 0.6328144073486328
# ---------- iteration 49 ----------
# total loss: 130.0316619873047
# train loss: 1.8601586524351144 ,  test loss: 4.243989666302999
# train acc: 0.6242283950617284 ,  test acc: 0.3333333333333333
# train hit: 0.8278042806519402 ,  test hit: 0.6406268527110418
# ---------- iteration 50 ----------
# total loss: 127.37242889404297
# train loss: 1.623058052710545 ,  test loss: 4.159697234630585
# train acc: 0.6620370370370371 ,  test acc: 0.3072916666666667
# train hit: 0.8486375161159185 ,  test hit: 0.6397587905327479
# ---------- iteration 51 ----------
# total loss: 118.82201385498047
# train loss: 1.5168213851657915 ,  test loss: 4.082901616891225
# train acc: 0.6682098765432098 ,  test acc: 0.328125
# train hit: 0.8533314186849712 ,  test hit: 0.6332484235366186
# ---------- iteration 52 ----------
# total loss: 114.3272476196289
# train loss: 1.3701746390189653 ,  test loss: 4.110573907693227
# train acc: 0.720679012345679 ,  test acc: 0.3229166666666667
# train hit: 0.8825879663596918 ,  test hit: 0.632814402381579
# ---------- iteration 53 ----------
# total loss: 111.31194305419922
# train loss: 1.288672230861805 ,  test loss: 4.109908580780029
# train acc: 0.716820987654321 ,  test acc: 0.3177083333333333
# train hit: 0.8813662639370671 ,  test hit: 0.6332484632730484
# ---------- iteration 54 ----------
# total loss: 106.40473937988281
# train loss: 1.417344840956323 ,  test loss: 4.030339320500691
# train acc: 0.6921296296296297 ,  test acc: 0.3020833333333333
# train hit: 0.8611760227768509 ,  test hit: 0.6406268030405045
# ---------- iteration 55 ----------
# total loss: 103.4834213256836
# train loss: 1.2423297549471444 ,  test loss: 4.108605643113454
# train acc: 0.7546296296296297 ,  test acc: 0.3333333333333333
# train hit: 0.8998203961937515 ,  test hit: 0.6432310144106547
# ---------- iteration 56 ----------
# total loss: 101.08661651611328
# train loss: 1.3653488792019126 ,  test loss: 4.215241054693858
# train acc: 0.7214506172839507 ,  test acc: 0.2916666666666667
# train hit: 0.8859315713246664 ,  test hit: 0.6419289459784826
# ---------- iteration 57 ----------
# total loss: 98.91387939453125
# train loss: 1.3559391851778384 ,  test loss: 4.245235979557037
# train acc: 0.7399691358024691 ,  test acc: 0.296875
# train hit: 0.8988559017946691 ,  test hit: 0.6367206672827402
# ---------- iteration 58 ----------
# total loss: 99.02078247070312
# train loss: 1.1387893506038336 ,  test loss: 4.174081087112427
# train acc: 0.7376543209876543 ,  test acc: 0.3333333333333333
# train hit: 0.887796276881371 ,  test hit: 0.6219638139009476
# ---------- iteration 59 ----------
# total loss: 89.26720428466797
# train loss: 1.0445338502342318 ,  test loss: 4.153534313042958
# train acc: 0.7631172839506173 ,  test acc: 0.3229166666666667
# train hit: 0.9067005183961656 ,  test hit: 0.6284741709629694
# ---------- iteration 60 ----------
# total loss: 84.47362518310547
# train loss: 0.9702017358791681 ,  test loss: 4.155972401301066
# train acc: 0.8063271604938271 ,  test acc: 0.3020833333333333
# train hit: 0.9238686480639894 ,  test hit: 0.6236998985211054
# ---------- iteration 61 ----------
# total loss: 79.79306030273438
# train loss: 0.9605850673016206 ,  test loss: 4.24273540576299
# train acc: 0.7970679012345679 ,  test acc: 0.3229166666666667
# train hit: 0.9189175455658524 ,  test hit: 0.6284742206335068
# ---------- iteration 62 ----------
# total loss: 75.82185363769531
# train loss: 0.9496664919970949 ,  test loss: 4.1123650670051575
# train acc: 0.7986111111111112 ,  test acc: 0.3125
# train hit: 0.919174740343918 ,  test hit: 0.626304050286611
# ---------- iteration 63 ----------
# total loss: 71.55718231201172
# train loss: 0.8705314692155814 ,  test loss: 4.131108244260152
# train acc: 0.8225308641975309 ,  test acc: 0.3072916666666667
# train hit: 0.9284982570895443 ,  test hit: 0.6310783376296362
# ---------- iteration 64 ----------
# total loss: 68.68789672851562
# train loss: 0.8378633076761975 ,  test loss: 4.121379494667053
# train acc: 0.8186728395061729 ,  test acc: 0.328125
# train hit: 0.9278552465968661 ,  test hit: 0.6358526150385538

# %%
epoch += 1 

trainer.model_save(epoch, './results/ec_base_model.pth')

# %%
trainer.model_valid(glove, './results/ec_base_valid.json')

# %%
print('train_ec_acc_every:', tra_acc1[-1], ', train_ec_acc_partof:', tra_acc2[-1], ', train_ec_acc_single:', tra_acc3[-1])
print('test_ec_acc_every:', tes_acc1[-1], ', test_ec_acc_partof:', tes_acc2[-1], ', test_ec_acc_single:', tes_acc3[-1])
print('train_ec_recall:', tra_hit2[-1], ', train_ec_precision:', tra_hit1[-1], ', train_ec_F1:', tra_hit3[-1])
print('test_ec_recall:', tes_hit2[-1], ', test_ec_precision:', tes_hit1[-1], ', test_ec_F1:', tes_hit3[-1])
# Out:
# train_ec_acc_every: 0.8186728395061729 , train_ec_acc_partof: 0.8966049382716049 , train_ec_acc_single: 0.9730902777777778
# test_ec_acc_every: 0.328125 , test_ec_acc_partof: 0.5520833333333334 , test_ec_acc_single: 0.8626302083333334
# train_ec_recall: 0.9278552465968661 , train_ec_precision: 0.9863040969695573 , train_ec_F1: 0.9561873040392799
# test_ec_recall: 0.6358526150385538 , test_ec_precision: 0.8237859259049097 , test_ec_F1: 0.7177207514403142

# %%
print('train_ec_acc_every_max:', max(tra_acc1), ', train_ec_acc_partof_max:', max(tra_acc2), ', train_ec_acc_single_max:', max(tra_acc3))
print('test_ec_acc_every_max:', max(tes_acc1), ', test_ec_acc_partof_max:', max(tes_acc2), ', test_ec_acc_single_max:', max(tes_acc3))
print('train_ec_recall_max:', max(tra_hit2), ', train_ec_precision_max:', max(tra_hit1), ', train_ec_F1_max:', max(tra_hit3))
print('test_ec_recall_max:', max(tes_hit2), ', test_ec_precision_max:', max(tes_hit1), ', test_ec_F1_max:', max(tes_hit3))
# Out:
# train_ec_acc_every_max: 0.8225308641975309 , train_ec_acc_partof_max: 0.8966049382716049 , train_ec_acc_single_max: 0.9738618827160493
# test_ec_acc_every_max: 0.3333333333333333 , test_ec_acc_partof_max: 0.5625 , test_ec_acc_single_max: 0.8665364583333334
# train_ec_recall_max: 0.9284982570895443 , train_ec_precision_max: 0.9864969974682655 , train_ec_F1_max: 0.9566193342707336
# test_ec_recall_max: 0.807292585571607 , test_ec_precision_max: 0.8420150130987167 , test_ec_F1_max: 0.7276435641236654

# %%
file = open("./results/ec_base_desc.txt",'w') 
print('train_ec_acc_every:', tra_acc1[-1], ', train_ec_acc_partof:', tra_acc2[-1], ', train_ec_acc_single:', tra_acc3[-1], file=file)
print('test_ec_acc_every:', tes_acc1[-1], ', test_ec_acc_partof:', tes_acc2[-1], ', test_ec_acc_single:', tes_acc3[-1], file=file)
print('train_ec_recall:', tra_hit2[-1], ', train_ec_precision:', tra_hit1[-1], ', train_ec_F1:', tra_hit3[-1], file=file)
print('test_ec_recall:', tes_hit2[-1], ', test_ec_precision:', tes_hit1[-1], ', test_ec_F1:', tes_hit3[-1], file=file)
print('', file=file)
print('train_ec_acc_every_max:', max(tra_acc1), ', train_ec_acc_partof_max:', max(tra_acc2), ', train_ec_acc_single_max:', max(tra_acc3), file=file)
print('test_ec_acc_every_max:', max(tes_acc1), ', test_ec_acc_partof_max:', max(tes_acc2), ', test_ec_acc_single_max:', max(tes_acc3), file=file)
print('train_ec_recall_max:', max(tra_hit2), ', train_ec_precision_max:', max(tra_hit1), ', train_ec_F1_max:', max(tra_hit3), file=file)
print('test_ec_recall_max:', max(tes_hit2), ', test_ec_precision_max:', max(tes_hit1), ', test_ec_F1_max:', max(tes_hit3), file=file)
print('', file=file)
print('train_ec_acc_every:', tra_acc1, file=file)
print('train_ec_acc_partof:', tra_acc2, file=file)
print('train_ec_acc_every:', tra_acc3, file=file)
print('test_ec_acc_every:', tes_acc1, file=file)
print('test_ec_acc_partof:', tes_acc2, file=file)
print('test_ec_acc_single:', tes_acc3, file=file)
print('train_ec_recall:', tra_hit2, file=file)
print('train_ec_precision:', tra_hit1, file=file)
print('train_ec_F1:', tra_hit3, file=file)
print('test_ec_recall:', tes_hit2, file=file)
print('test_ec_precision:', tes_hit1, file=file)
print('test_ec_F1:', tes_hit3, file=file)
file.close()

# %%
x_range = list(range(1, len(tra_loss) + 1))
fig = plt.figure(num=1, figsize=(15, 10), dpi=100, clear=True)
plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, hspace=0.3, wspace=0.3)
ax1 = fig.add_subplot(2, 3, 1)
ax2 = fig.add_subplot(2, 3, 2)
ax3 = fig.add_subplot(2, 3, 3)
ax4 = fig.add_subplot(2, 3, 4)
ax5 = fig.add_subplot(2, 3, 5)
ax6 = fig.add_subplot(2, 3, 6)

l1, = ax1.plot(x_range, tra_loss, c='g', lw='2')
ax1.set_title('(a) train loss', fontsize=16)
ax1.set_xlabel('iteration', fontsize=16)
ax1.set_ylabel('loss', fontsize=16)
ax1.legend([l1], ['training set'], fontsize=12)  

l1,  = ax4.plot(x_range, tes_loss, c='g', lw='2')
ax4.set_title('(b) test loss', fontsize=16)
ax4.set_xlabel('iteration', fontsize=16)
ax4.set_ylabel('loss', fontsize=16)
ax4.legend([l1], ['testing set'], fontsize=12)  

l1,  = ax2.plot(x_range, tra_acc1, c='b', lw='2')
l2,  = ax2.plot(x_range, tra_acc2, c='m', lw='2')
l3,  = ax2.plot(x_range, tra_acc3, c='r', lw='2')
ax2.set_title('(c) train accuracy', fontsize=16)
ax2.set_xlabel('iteration', fontsize=16)
ax2.set_ylabel('accuracy', fontsize=16)
ax2.set_ylim((0, 1))
ax2.legend([l1, l2, l3], ['every', 'partof', 'single'], fontsize=12)  

l1,  = ax5.plot(x_range, tes_acc1, c='b', lw='2')
l2,  = ax5.plot(x_range, tes_acc2, c='m', lw='2')
l3,  = ax5.plot(x_range, tes_acc3, c='r', lw='2')
ax5.set_title('(d) test accuracy', fontsize=16)
ax5.set_xlabel('iteration', fontsize=16)
ax5.set_ylabel('accuracy', fontsize=16)
ax5.set_ylim((0, 1))
ax5.legend([l1, l2, l3], ['every', 'partof', 'single'], fontsize=12)  

l1,  = ax3.plot(x_range, tra_hit1, c=seaborn.xkcd_rgb['green'], lw='2')
l2,  = ax3.plot(x_range, tra_hit2, c=seaborn.xkcd_rgb['deep sky blue'], lw='2')
l3,  = ax3.plot(x_range, tra_hit3, c=seaborn.xkcd_rgb['turquoise'], lw='2')
ax3.set_title('(e) train hit rate', fontsize=16)
ax3.set_xlabel('iteration', fontsize=16)
ax3.set_ylabel('hit rate', fontsize=16)
ax3.set_ylim((0, 1))
ax3.legend([l2, l3, l1], ['recall', 'f1', 'prec'], fontsize=12)  

l1,  = ax6.plot(x_range, tes_hit1, c=seaborn.xkcd_rgb['green'], lw='2')
l2,  = ax6.plot(x_range, tes_hit2, c=seaborn.xkcd_rgb['deep sky blue'], lw='2')
l3,  = ax6.plot(x_range, tes_hit3, c=seaborn.xkcd_rgb['turquoise'], lw='2')
ax6.set_title('(f) test hit rate', fontsize=16)
ax6.set_xlabel('iteration', fontsize=16)
ax6.set_ylabel('hit rate', fontsize=16)
ax6.set_ylim((0, 1))
ax6.legend([l2, l3, l1], ['recall', 'f1', 'prec'], fontsize=12)  

plt.savefig('./results/ec_base_total.jpg')
