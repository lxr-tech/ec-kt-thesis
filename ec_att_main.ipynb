# %%
import json
import torch
import seaborn
import matplotlib as mpl
import matplotlib.pyplot as plt
from ec_att_model import get_ec_batch, EC, ECData
from ec_gen_train import Trainer, name_list

mpl.rcParams['font.sans-serif'] = ['DengXian']  
mpl.rcParams['axes.unicode_minus'] = False

# %%
with open('./problem_data_a.json', 'r', encoding='utf8')as fp:
    data = json.load(fp)
with open('glove.6B.50d.txt', 'rb') as f:
    lines = f.readlines()

# %%
name_dict = dict()
for i, name in enumerate(name_list):
    name_dict[name] = i

# %%
trained_dict = dict()
for i in range(len(lines)):
    line = lines[i].split()
    trained_dict[line[0].decode("utf-8").upper()] = [float(line[j]) for j in range(1, 51)]

# %%
alpha = 5e-4
epoch_num = 150
mid_size = 10
batch_size = 16
weight_decay = 5e-4
max_grad_norm = -1

# %%
glove = ECData(data=data, name_dict=name_dict, trained_dict=trained_dict, 
                       train_path='./ec_train_data.json', test_path='./ec_test_data.json')
glove.get_words()
glove.get_id()

# %%
train_data = get_ec_batch(glove.train_content, glove.train_y, batch_size)
test_data = get_ec_batch(glove.test_content, glove.test_y, batch_size)
print(len(train_data), len(test_data), len(test_data) / (len(test_data) + len(train_data)))
# Out:
# 81 12 0.12903225806451613

# %%
torch.manual_seed(0)
torch.cuda.manual_seed(0)
tra_acc1, tes_acc1 = list(), list()
tra_acc2, tes_acc2 = list(), list()
tra_acc3, tes_acc3 = list(), list()
tra_loss, tes_loss = list(), list()
tra_hit1, tes_hit1 = list(), list()
tra_hit2, tes_hit2 = list(), list()
tra_hit3, tes_hit3 = list(), list()

# %%
model = EC(inp_size=50, mid_size=mid_size, num_words=glove.word_num, num_types=len(name_list), num_layers=1,
              weight=torch.tensor(glove.embedding, dtype=torch.float))

# %%
trainer = Trainer(model=model, train_data=train_data, epoch_num=epoch_num,
                  batch_size=batch_size, alpha=alpha, weight_decay=weight_decay, max_grad_norm=max_grad_norm)
epoch = 0

# %%
for epoch in range(epoch_num):
    loss_tot = torch.Tensor([0]).cuda()
    loss_tot += trainer.train_func()

    train_loss, train_acc1, train_acc2, train_acc3, train_hit1, train_hit2, train_hit3 = trainer.model_eval(train_data)
    test_loss, test_acc1, test_acc2, test_acc3, test_hit1, test_hit2, test_hit3 = trainer.model_eval(test_data)

    tra_loss.append(train_loss / len(train_data) / batch_size)
    tes_loss.append(test_loss / len(test_data) / batch_size)
    tra_acc1.append(train_acc1)
    tes_acc1.append(test_acc1)
    tra_acc2.append(train_acc2)
    tes_acc2.append(test_acc2)
    tra_acc3.append(train_acc3)
    tes_acc3.append(test_acc3)
    tra_hit1.append(train_hit1)
    tes_hit1.append(test_hit1)
    tra_hit2.append(train_hit2)
    tes_hit2.append(test_hit2)
    tra_hit3.append(train_hit3)
    tes_hit3.append(test_hit3)
    print("---------- iteration", epoch + 1, "----------")
    print("total loss:", loss_tot.item())
    print("train loss:", train_loss / len(train_data), ", ", "test loss:", test_loss / len(test_data))
    print("train acc:", train_acc1, ", ", "test acc:", test_acc1)
    print("train hit:", train_hit2, ", ", "test hit:", test_hit2)
    if train_acc1 > 0.23 and test_acc1 > 0.25:
        break
# Out:
# D:\PyCharmProjects\ecnu-EduKTM\paper2a\ec_gen_train.py:67: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   acc = torch.mean((torch.tensor(pred == y, dtype=torch.float)))
# ---------- iteration 1 ----------
# total loss: 653.2814331054688
# train loss: 7.634059723512626 ,  test loss: 7.542836308479309
# train acc: 0.0007716049382716049 ,  test acc: 0.0
# train hit: 0.8159088080311999 ,  test hit: 0.8854172279437383
# ---------- iteration 2 ----------
# total loss: 623.874267578125
# train loss: 7.320349245895574 ,  test loss: 7.260003368059794
# train acc: 0.0023148148148148147 ,  test acc: 0.0
# train hit: 0.7575886727851114 ,  test hit: 0.8333341429630915
# ---------- iteration 3 ----------
# total loss: 613.3095703125
# train loss: 7.221010096279191 ,  test loss: 7.151383837064107
# train acc: 0.0007716049382716049 ,  test acc: 0.0
# train hit: 0.8054922002333181 ,  test hit: 0.8663200885057449
# ---------- iteration 4 ----------
# total loss: 607.5107421875
# train loss: 7.158136868182524 ,  test loss: 7.068624456723531
# train acc: 0.0007716049382716049 ,  test acc: 0.0
# train hit: 0.8207313227064815 ,  test hit: 0.8897574742635092
# ---------- iteration 5 ----------
# total loss: 599.8956298828125
# train loss: 7.092179292514 ,  test loss: 6.977354049682617
# train acc: 0.004629629629629629 ,  test acc: 0.0
# train hit: 0.6803001529640622 ,  test hit: 0.7656262914339701
# ---------- iteration 6 ----------
# total loss: 597.6581420898438
# train loss: 7.045428970713674 ,  test loss: 6.901512145996094
# train acc: 0.015432098765432098 ,  test acc: 0.005208333333333333
# train hit: 0.6369619111955902 ,  test hit: 0.7283000697692236
# ---------- iteration 7 ----------
# total loss: 587.5828857421875
# train loss: 7.043893531516746 ,  test loss: 6.909084518750508
# train acc: 0.019290123456790122 ,  test acc: 0.005208333333333333
# train hit: 0.6381193053575209 ,  test hit: 0.7256959428389868
# ---------- iteration 8 ----------
# total loss: 584.8583984375
# train loss: 6.980671735457432 ,  test loss: 6.853921850522359
# train acc: 0.021604938271604937 ,  test acc: 0.015625
# train hit: 0.6472498689904626 ,  test hit: 0.7395847539107004
# ---------- iteration 9 ----------
# total loss: 578.028076171875
# train loss: 6.92070006146843 ,  test loss: 6.7741871277491255
# train acc: 0.021604938271604937 ,  test acc: 0.010416666666666666
# train hit: 0.6357401782347832 ,  test hit: 0.7335083931684494
# ---------- iteration 10 ----------
# total loss: 573.3540649414062
# train loss: 6.856617056293252 ,  test loss: 6.739217917124431
# train acc: 0.020833333333333332 ,  test acc: 0.015625
# train hit: 0.6601741678184934 ,  test hit: 0.7491333037614822
# ---------- iteration 11 ----------
# total loss: 569.8543090820312
# train loss: 6.790321497269619 ,  test loss: 6.640998363494873
# train acc: 0.020061728395061727 ,  test acc: 0.005208333333333333
# train hit: 0.675670478446984 ,  test hit: 0.7560777217149734
# ---------- iteration 12 ----------
# total loss: 564.2535400390625
# train loss: 6.732940844547602 ,  test loss: 6.5567701657613116
# train acc: 0.023148148148148147 ,  test acc: 0.010416666666666666
# train hit: 0.6545800515163092 ,  test hit: 0.7439249952634176
# ---------- iteration 13 ----------
# total loss: 559.784912109375
# train loss: 6.692274176044228 ,  test loss: 6.516740600268046
# train acc: 0.022376543209876542 ,  test acc: 0.010416666666666666
# train hit: 0.6650609646314456 ,  test hit: 0.7491333037614822
# ---------- iteration 14 ----------
# total loss: 556.0903930664062
# train loss: 6.650249893282667 ,  test loss: 6.472907304763794
# train acc: 0.023148148148148147 ,  test acc: 0.015625
# train hit: 0.6581808468441904 ,  test hit: 0.7413208385308584
# ---------- iteration 15 ----------
# total loss: 552.6036987304688
# train loss: 6.595870836281482 ,  test loss: 6.421977361043294
# train acc: 0.023919753086419752 ,  test acc: 0.010416666666666666
# train hit: 0.672712653507421 ,  test hit: 0.7491332987944285
# ---------- iteration 16 ----------
# total loss: 548.3132934570312
# train loss: 6.535301602916953 ,  test loss: 6.333928465843201
# train acc: 0.023919753086419752 ,  test acc: 0.010416666666666666
# train hit: 0.6753489588513787 ,  test hit: 0.7534735302130381
# ---------- iteration 17 ----------
# total loss: 544.2642822265625
# train loss: 6.487236552768284 ,  test loss: 6.286507407824199
# train acc: 0.023919753086419752 ,  test acc: 0.010416666666666666
# train hit: 0.6729055562137086 ,  test hit: 0.7534735252459844
# ---------- iteration 18 ----------
# total loss: 539.1156005859375
# train loss: 6.43555083098235 ,  test loss: 6.240509072939555
# train acc: 0.024691358024691357 ,  test acc: 0.010416666666666666
# train hit: 0.6859584678838282 ,  test hit: 0.7560776819785436
# ---------- iteration 19 ----------
# total loss: 534.7651977539062
# train loss: 6.4170245123498235 ,  test loss: 6.187620520591736
# train acc: 0.023148148148148147 ,  test acc: 0.010416666666666666
# train hit: 0.6873087802051027 ,  test hit: 0.7517374207576116
# ---------- iteration 20 ----------
# total loss: 532.77880859375
# train loss: 6.34980579070103 ,  test loss: 6.166075110435486
# train acc: 0.023919753086419752 ,  test acc: 0.010416666666666666
# train hit: 0.6929028747994223 ,  test hit: 0.7560776819785436
# ---------- iteration 21 ----------
# total loss: 525.6382446289062
# train loss: 6.2924237427888094 ,  test loss: 6.146611332893372
# train acc: 0.023919753086419752 ,  test acc: 0.010416666666666666
# train hit: 0.6988827740704572 ,  test hit: 0.7560776819785436
# ---------- iteration 22 ----------
# total loss: 522.0585327148438
# train loss: 6.234289528411112 ,  test loss: 6.143834153811137
# train acc: 0.024691358024691357 ,  test acc: 0.010416666666666666
# train hit: 0.7085920837190416 ,  test hit: 0.7604179382324219
# ---------- iteration 23 ----------
# total loss: 516.50390625
# train loss: 6.184682357458421 ,  test loss: 6.117544849713643
# train acc: 0.024691358024691357 ,  test acc: 0.015625
# train hit: 0.7118713899894997 ,  test hit: 0.7604179382324219
# ---------- iteration 24 ----------
# total loss: 512.5728149414062
# train loss: 6.140261279212104 ,  test loss: 6.0296198924382525
# train acc: 0.024691358024691357 ,  test acc: 0.015625
# train hit: 0.7129644920796524 ,  test hit: 0.7552096347014109
# ---------- iteration 25 ----------
# total loss: 508.5710754394531
# train loss: 6.0495699364462014 ,  test loss: 6.054586887359619
# train acc: 0.024691358024691357 ,  test acc: 0.010416666666666666
# train hit: 0.7408063912097319 ,  test hit: 0.7617200165987015
# ---------- iteration 26 ----------
# total loss: 503.2841491699219
# train loss: 6.024203689010055 ,  test loss: 6.010610858599345
# train acc: 0.02546296296296296 ,  test acc: 0.010416666666666666
# train hit: 0.7379128822573909 ,  test hit: 0.7604179382324219
# ---------- iteration 27 ----------
# total loss: 499.0011901855469
# train loss: 5.948354002870159 ,  test loss: 6.003527005513509
# train acc: 0.02546296296296296 ,  test acc: 0.010416666666666666
# train hit: 0.7469149070021547 ,  test hit: 0.7604179382324219
# ---------- iteration 28 ----------
# total loss: 493.53399658203125
# train loss: 5.894892239276274 ,  test loss: 6.026307384173076
# train acc: 0.02546296296296296 ,  test acc: 0.015625
# train hit: 0.75565970900618 ,  test hit: 0.7569457391897837
# ---------- iteration 29 ----------
# total loss: 487.84326171875
# train loss: 5.816648898301302 ,  test loss: 5.966610948244731
# train acc: 0.024691358024691357 ,  test acc: 0.010416666666666666
# train hit: 0.7681339272746334 ,  test hit: 0.7651922305425009
# ---------- iteration 30 ----------
# total loss: 480.47637939453125
# train loss: 5.74960646217252 ,  test loss: 5.91992727915446
# train acc: 0.02546296296296296 ,  test acc: 0.010416666666666666
# train hit: 0.7719919350412157 ,  test hit: 0.7547756383816401
# ---------- iteration 31 ----------
# total loss: 474.28863525390625
# train loss: 5.687493851155411 ,  test loss: 5.904741803805034
# train acc: 0.027777777777777776 ,  test acc: 0.010416666666666666
# train hit: 0.7685197554988625 ,  test hit: 0.7560777167479197
# ---------- iteration 32 ----------
# total loss: 467.5892028808594
# train loss: 5.582463052537706 ,  test loss: 5.868170619010925
# train acc: 0.17824074074074073 ,  test acc: 0.19791666666666666
# train hit: 0.7027409315845112 ,  test hit: 0.7070329040288925
# ---------- iteration 33 ----------
# total loss: 461.4977722167969
# train loss: 5.488859980194657 ,  test loss: 5.946847081184387
# train acc: 0.18595679012345678 ,  test acc: 0.203125
# train hit: 0.6944462553954419 ,  test hit: 0.7005226165056229
# ---------- iteration 34 ----------
# total loss: 452.5947570800781
# train loss: 5.468675030602349 ,  test loss: 5.8024788697560625
# train acc: 0.22299382716049382 ,  test acc: 0.265625
# train hit: 0.6361261860088065 ,  test hit: 0.6215301255385081
# ---------- iteration 35 ----------
# total loss: 443.5986328125
# train loss: 5.431236370110217 ,  test loss: 5.756509820620219
# train acc: 0.22916666666666666 ,  test acc: 0.28125
# train hit: 0.6116921923778675 ,  test hit: 0.6111135631799698
# ---------- iteration 36 ----------
# total loss: 438.314697265625
# train loss: 5.378366184823307 ,  test loss: 5.717001914978027
# train acc: 0.22993827160493827 ,  test acc: 0.28125
# train hit: 0.6130424793119784 ,  test hit: 0.6102455109357834
# ---------- iteration 37 ----------
# total loss: 431.37701416015625
# train loss: 5.302657221570427 ,  test loss: 5.732484579086304
# train acc: 0.23842592592592593 ,  test acc: 0.2760416666666667
# train hit: 0.6217229782063284 ,  test hit: 0.6059052497148514

# %%
epoch += 1 

trainer.model_save(epoch, './results/ec_att_model.pth')

# %%
trainer.model_valid(glove, './results/ec_att_valid.json')

# %%
print('train_ec_acc_every:', tra_acc1[-1], ', train_ec_acc_partof:', tra_acc2[-1], ', train_ec_acc_single:', tra_acc3[-1])
print('test_ec_acc_every:', tes_acc1[-1], ', test_ec_acc_partof:', tes_acc2[-1], ', test_ec_acc_single:', tes_acc3[-1])
print('train_ec_recall:', tra_hit2[-1], ', train_ec_precision:', tra_hit1[-1], ', train_ec_F1:', tra_hit3[-1])
print('test_ec_recall:', tes_hit2[-1], ', test_ec_precision:', tes_hit1[-1], ', test_ec_F1:', tes_hit3[-1])
# Out:
# train_ec_acc_every: 0.23842592592592593 , train_ec_acc_partof: 0.35185185185185186 , train_ec_acc_single: 0.8279320987654321
# test_ec_acc_every: 0.2760416666666667 , test_ec_acc_partof: 0.4270833333333333 , test_ec_acc_single: 0.8287760416666666
# train_ec_recall: 0.6217229782063284 , train_ec_precision: 0.632641476245574 , train_ec_F1: 0.6271347077036107
# test_ec_recall: 0.6059052497148514 , test_ec_precision: 0.6284748439987501 , test_ec_F1: 0.6169837139012007

# %%
print('train_ec_acc_every_max:', max(tra_acc1), ', train_ec_acc_partof_max:', max(tra_acc2), ', train_ec_acc_single_max:', max(tra_acc3))
print('test_ec_acc_every_max:', max(tes_acc1), ', test_ec_acc_partof_max:', max(tes_acc2), ', test_ec_acc_single_max:', max(tes_acc3))
print('train_ec_recall_max:', max(tra_hit2), ', train_ec_precision_max:', max(tra_hit1), ', train_ec_F1_max:', max(tra_hit3))
print('test_ec_recall_max:', max(tes_hit2), ', test_ec_precision_max:', max(tes_hit1), ', test_ec_F1_max:', max(tes_hit3))
# Out:
# train_ec_acc_every_max: 0.23842592592592593 , train_ec_acc_partof_max: 0.35185185185185186 , train_ec_acc_single_max: 0.8279320987654321
# test_ec_acc_every_max: 0.28125 , test_ec_acc_partof_max: 0.4375 , test_ec_acc_single_max: 0.8287760416666666
# train_ec_recall_max: 0.8207313227064815 , train_ec_precision_max: 0.632641476245574 , train_ec_F1_max: 0.6528185408249818
# test_ec_recall_max: 0.8897574742635092 , test_ec_precision_max: 0.6367212533950806 , test_ec_F1_max: 0.6405561304984602

# %%
file = open("./results/ec_att_desc.txt",'w') 
print('train_ec_acc_every:', tra_acc1[-1], ', train_ec_acc_partof:', tra_acc2[-1], ', train_ec_acc_single:', tra_acc3[-1], file=file)
print('test_ec_acc_every:', tes_acc1[-1], ', test_ec_acc_partof:', tes_acc2[-1], ', test_ec_acc_single:', tes_acc3[-1], file=file)
print('train_ec_recall:', tra_hit2[-1], ', train_ec_precision:', tra_hit1[-1], ', train_ec_F1:', tra_hit3[-1], file=file)
print('test_ec_recall:', tes_hit2[-1], ', test_ec_precision:', tes_hit1[-1], ', test_ec_F1:', tes_hit3[-1], file=file)
print('', file=file)
print('train_ec_acc_every_max:', max(tra_acc1), ', train_ec_acc_partof_max:', max(tra_acc2), ', train_ec_acc_single_max:', max(tra_acc3), file=file)
print('test_ec_acc_every_max:', max(tes_acc1), ', test_ec_acc_partof_max:', max(tes_acc2), ', test_ec_acc_single_max:', max(tes_acc3), file=file)
print('train_ec_recall_max:', max(tra_hit2), ', train_ec_precision_max:', max(tra_hit1), ', train_ec_F1_max:', max(tra_hit3), file=file)
print('test_ec_recall_max:', max(tes_hit2), ', test_ec_precision_max:', max(tes_hit1), ', test_ec_F1_max:', max(tes_hit3), file=file)
print('', file=file)
print('train_ec_acc_every:', tra_acc1, file=file)
print('train_ec_acc_partof:', tra_acc2, file=file)
print('train_ec_acc_every:', tra_acc3, file=file)
print('test_ec_acc_every:', tes_acc1, file=file)
print('test_ec_acc_partof:', tes_acc2, file=file)
print('test_ec_acc_single:', tes_acc3, file=file)
print('train_ec_recall:', tra_hit2, file=file)
print('train_ec_precision:', tra_hit1, file=file)
print('train_ec_F1:', tra_hit3, file=file)
print('test_ec_recall:', tes_hit2, file=file)
print('test_ec_precision:', tes_hit1, file=file)
print('test_ec_F1:', tes_hit3, file=file)
file.close()

# %%
x_range = list(range(1, epoch+1))
fig = plt.figure(num=1, figsize=(15, 10), dpi=100, clear=True)
plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, hspace=0.3, wspace=0.3)
ax1 = fig.add_subplot(2, 3, 1)
ax2 = fig.add_subplot(2, 3, 2)
ax3 = fig.add_subplot(2, 3, 3)
ax4 = fig.add_subplot(2, 3, 4)
ax5 = fig.add_subplot(2, 3, 5)
ax6 = fig.add_subplot(2, 3, 6)

l1, = ax1.plot(x_range, tra_loss, c='g', lw='2')
ax1.set_title('(a) train loss', fontsize=16)
ax1.set_xlabel('iteration', fontsize=16)
ax1.set_ylabel('loss', fontsize=16)
ax1.legend([l1], ['training set'], fontsize=12)  

l1,  = ax4.plot(x_range, tes_loss, c='g', lw='2')
ax4.set_title('(b) test loss', fontsize=16)
ax4.set_xlabel('iteration', fontsize=16)
ax4.set_ylabel('loss', fontsize=16)
ax4.legend([l1], ['testing set'], fontsize=12)  

l1,  = ax2.plot(x_range, tra_acc1, c='b', lw='2')
l2,  = ax2.plot(x_range, tra_acc2, c='m', lw='2')
l3,  = ax2.plot(x_range, tra_acc3, c='r', lw='2')
ax2.set_title('(c) train accuracy', fontsize=16)
ax2.set_xlabel('iteration', fontsize=16)
ax2.set_ylabel('accuracy', fontsize=16)
ax2.set_ylim((0, 1))
ax2.legend([l1, l2, l3], ['every', 'partof', 'single'], fontsize=12)  

l1,  = ax5.plot(x_range, tes_acc1, c='b', lw='2')
l2,  = ax5.plot(x_range, tes_acc2, c='m', lw='2')
l3,  = ax5.plot(x_range, tes_acc3, c='r', lw='2')
ax5.set_title('(d) test accuracy', fontsize=16)
ax5.set_xlabel('iteration', fontsize=16)
ax5.set_ylabel('accuracy', fontsize=16)
ax5.set_ylim((0, 1))
ax5.legend([l1, l2, l3], ['every', 'partof', 'single'], fontsize=12)  

l1,  = ax3.plot(x_range, tra_hit1, c=seaborn.xkcd_rgb['green'], lw='2')
l2,  = ax3.plot(x_range, tra_hit2, c=seaborn.xkcd_rgb['deep sky blue'], lw='2')
l3,  = ax3.plot(x_range, tra_hit3, c=seaborn.xkcd_rgb['turquoise'], lw='2')
ax3.set_title('(e) train hit rate', fontsize=16)
ax3.set_xlabel('iteration', fontsize=16)
ax3.set_ylabel('hit rate', fontsize=16)
ax3.set_ylim((0, 1))
ax3.legend([l2, l3, l1], ['recall', 'f1', 'prec'], fontsize=12)  

l1,  = ax6.plot(x_range, tes_hit1, c=seaborn.xkcd_rgb['green'], lw='2')
l2,  = ax6.plot(x_range, tes_hit2, c=seaborn.xkcd_rgb['deep sky blue'], lw='2')
l3,  = ax6.plot(x_range, tes_hit3, c=seaborn.xkcd_rgb['turquoise'], lw='2')
ax6.set_title('(f) test hit rate', fontsize=16)
ax6.set_xlabel('iteration', fontsize=16)
ax6.set_ylabel('hit rate', fontsize=16)
ax6.set_ylim((0, 1))
ax6.legend([l2, l3, l1], ['recall', 'f1', 'prec'], fontsize=12)  

plt.savefig('./results/ec_att_total.jpg')
